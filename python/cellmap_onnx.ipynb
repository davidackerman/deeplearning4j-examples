# %%
from funlib.geometry import Coordinate
from dacapo.experiments.architectures import CNNectomeUNetConfig
from dacapo.experiments.tasks.distance_task_config import DistanceTaskConfig

import torch

input_voxel_size = (16, 16, 16)
output_voxel_size = (8, 8, 8)

channels = [
    "ecs",  # extra cellular space
    "plasma_membrane",
    "mito",
    "mito_membrane",
    "vesicle",
    "vesicle_membrane",
    "mvb",  # endosomes
    "mvb_membrane",
    "er",
    "er_membrane",
    "eres",
    "nucleus",
    "microtubules",
    "microtubules_out",
]

architecture_config = CNNectomeUNetConfig(
    name="CellMapArchitecture",
    input_shape=Coordinate(
        216, 216, 216
    ),  # can be changed
    eval_shape_increase=Coordinate(
        72, 72, 72
    ),  # can be changed
    fmaps_in=1,
    num_fmaps=12,
    fmaps_out=72,
    fmap_inc_factor=6,
    downsample_factors=[(2, 2, 2), (3, 3, 3), (3, 3, 3)],
    constant_upsample=True,
    upsample_factors=[(2, 2, 2)],
)

task_config = DistanceTaskConfig(
    name="DistancePrediction",
    # important
    channels=channels,
    scale_factor=50,  # target = tanh(distance / scale)
    # training
    mask_distances=True,
    # evaluation
    clip_distance=50,
    tol_distance=10,
)

# create backbone from config
architecture = architecture_config.architecture_type(architecture_config)

# initialize task from config
task = task_config.task_type(task_config)

# adding final layers/activations to create the model
model = task.create_model(architecture)


path_to_weights = "/nrs/cellmap/pattonw/crop_num_experiment/scratch_distances_many_all_many_8nm_upsample-unet_default__2/checkpoints/mito__f1_score"
weights = torch.load(path_to_weights, map_location="cuda")
model.load_state_dict(weights["model"])
model.to("cuda")
import numpy as np
x = torch.rand((1, 1, 216,216,216))

# set model to input mode
model.eval()

# Export the model
torch.onnx.export(model,                     # model being run
                  x.to("cuda"),                         # model input (or a tuple for multiple inputs)
                  "cellmap_model.onnx",      # where to save the model (can be a file or file-like object)
                  export_params=True,        # store the trained parameter weights inside the model file
                  opset_version=11,          # the ONNX version to export the model to
                  do_constant_folding=True,  # whether to execute constant folding for optimization
                  input_names = ['input'],   # the model's input names
                  output_names = ['output'], # the model's output names
                  dynamic_axes={'input' : {0 : 'batch_size'},    # variable length axes
                                'output' : {0 : 'batch_size'}},
#verbose=True,
)

# %%
import onnx

# Load the ONNX model
model = onnx.load("cellmap_model.onnx")

# Check it is well-formed
onnx.checker.check_model(model)

print(onnx.helper.printable_graph(model.graph))
# Out:
# graph torch-jit-export (
#   %input[FLOAT, batch_sizex1x216x216x216]
# ) initializers (
#   %architecture.unet.0.l_conv.0.conv_pass.0.weight[FLOAT, 12x1x3x3x3]
#   %architecture.unet.0.l_conv.0.conv_pass.0.bias[FLOAT, 12]
#   %architecture.unet.0.l_conv.0.conv_pass.2.weight[FLOAT, 12x12x3x3x3]
#   %architecture.unet.0.l_conv.0.conv_pass.2.bias[FLOAT, 12]
#   %architecture.unet.0.l_conv.1.conv_pass.0.weight[FLOAT, 72x12x3x3x3]
#   %architecture.unet.0.l_conv.1.conv_pass.0.bias[FLOAT, 72]
#   %architecture.unet.0.l_conv.1.conv_pass.2.weight[FLOAT, 72x72x3x3x3]
#   %architecture.unet.0.l_conv.1.conv_pass.2.bias[FLOAT, 72]
#   %architecture.unet.0.l_conv.2.conv_pass.0.weight[FLOAT, 432x72x3x3x3]
#   %architecture.unet.0.l_conv.2.conv_pass.0.bias[FLOAT, 432]
#   %architecture.unet.0.l_conv.2.conv_pass.2.weight[FLOAT, 432x432x3x3x3]
#   %architecture.unet.0.l_conv.2.conv_pass.2.bias[FLOAT, 432]
#   %architecture.unet.0.l_conv.3.conv_pass.0.weight[FLOAT, 2592x432x3x3x3]
#   %architecture.unet.0.l_conv.3.conv_pass.0.bias[FLOAT, 2592]
#   %architecture.unet.0.l_conv.3.conv_pass.2.weight[FLOAT, 2592x2592x3x3x3]
#   %architecture.unet.0.l_conv.3.conv_pass.2.bias[FLOAT, 2592]
#   %architecture.unet.0.r_up.0.0.up.1.weight[FLOAT, 72x72x1x1x1]
#   %architecture.unet.0.r_up.0.0.up.1.bias[FLOAT, 72]
#   %architecture.unet.0.r_up.0.1.up.1.weight[FLOAT, 72x432x1x1x1]
#   %architecture.unet.0.r_up.0.1.up.1.bias[FLOAT, 72]
#   %architecture.unet.0.r_up.0.2.up.1.weight[FLOAT, 432x2592x1x1x1]
#   %architecture.unet.0.r_up.0.2.up.1.bias[FLOAT, 432]
#   %architecture.unet.0.r_conv.0.0.conv_pass.0.weight[FLOAT, 72x84x3x3x3]
#   %architecture.unet.0.r_conv.0.0.conv_pass.0.bias[FLOAT, 72]
#   %architecture.unet.0.r_conv.0.0.conv_pass.2.weight[FLOAT, 72x72x3x3x3]
#   %architecture.unet.0.r_conv.0.0.conv_pass.2.bias[FLOAT, 72]
#   %architecture.unet.0.r_conv.0.1.conv_pass.0.weight[FLOAT, 72x144x3x3x3]
#   %architecture.unet.0.r_conv.0.1.conv_pass.0.bias[FLOAT, 72]
#   %architecture.unet.0.r_conv.0.1.conv_pass.2.weight[FLOAT, 72x72x3x3x3]
#   %architecture.unet.0.r_conv.0.1.conv_pass.2.bias[FLOAT, 72]
#   %architecture.unet.0.r_conv.0.2.conv_pass.0.weight[FLOAT, 432x864x3x3x3]
#   %architecture.unet.0.r_conv.0.2.conv_pass.0.bias[FLOAT, 432]
#   %architecture.unet.0.r_conv.0.2.conv_pass.2.weight[FLOAT, 432x432x3x3x3]
#   %architecture.unet.0.r_conv.0.2.conv_pass.2.bias[FLOAT, 432]
#   %architecture.unet.1.up.1.weight[FLOAT, 72x72x1x1x1]
#   %architecture.unet.1.up.1.bias[FLOAT, 72]
#   %architecture.unet.2.conv_pass.0.weight[FLOAT, 72x72x3x3x3]
#   %architecture.unet.2.conv_pass.0.bias[FLOAT, 72]
#   %architecture.unet.2.conv_pass.2.weight[FLOAT, 72x72x3x3x3]
#   %architecture.unet.2.conv_pass.2.bias[FLOAT, 72]
#   %prediction_head.weight[FLOAT, 14x72x1x1x1]
#   %prediction_head.bias[FLOAT, 14]
#   %onnx::Resize_641[FLOAT, 5]
#   %onnx::Slice_642[INT64, 1]
#   %onnx::Slice_643[INT64, 1]
#   %onnx::Slice_644[INT64, 1]
#   %onnx::Slice_645[INT64, 1]
#   %onnx::Slice_646[INT64, 1]
#   %onnx::Slice_647[INT64, 1]
#   %onnx::Slice_648[INT64, 1]
#   %onnx::Slice_649[INT64, 1]
#   %onnx::Slice_650[INT64, 1]
#   %onnx::Slice_651[INT64, 1]
#   %onnx::Resize_652[FLOAT, 5]
#   %onnx::Slice_653[INT64, 1]
#   %onnx::Slice_654[INT64, 1]
#   %onnx::Slice_655[INT64, 1]
#   %onnx::Slice_656[INT64, 1]
#   %onnx::Slice_657[INT64, 1]
#   %onnx::Slice_658[INT64, 1]
#   %onnx::Slice_659[INT64, 1]
#   %onnx::Slice_660[INT64, 1]
#   %onnx::Slice_661[INT64, 1]
#   %onnx::Slice_662[INT64, 1]
#   %onnx::Resize_663[FLOAT, 5]
#   %onnx::Slice_664[INT64, 1]
#   %onnx::Slice_665[INT64, 1]
#   %onnx::Slice_666[INT64, 1]
#   %onnx::Slice_667[INT64, 1]
#   %onnx::Slice_668[INT64, 1]
#   %onnx::Slice_669[INT64, 1]
#   %onnx::Slice_670[INT64, 1]
#   %onnx::Slice_671[INT64, 1]
#   %onnx::Slice_672[INT64, 1]
#   %onnx::Slice_673[INT64, 1]
#   %onnx::Resize_674[FLOAT, 5]
# ) {
#   %input.1 = Conv[dilations = [1, 1, 1], group = 1, kernel_shape = [3, 3, 3], pads = [0, 0, 0, 0, 0, 0], strides = [1, 1, 1]](%input, %architecture.unet.0.l_conv.0.conv_pass.0.weight, %architecture.unet.0.l_conv.0.conv_pass.0.bias)
#   %input.4 = Relu(%input.1)
#   %input.8 = Conv[dilations = [1, 1, 1], group = 1, kernel_shape = [3, 3, 3], pads = [0, 0, 0, 0, 0, 0], strides = [1, 1, 1]](%input.4, %architecture.unet.0.l_conv.0.conv_pass.2.weight, %architecture.unet.0.l_conv.0.conv_pass.2.bias)
#   %f_left = Relu(%input.8)
#   %input.12 = MaxPool[ceil_mode = 0, kernel_shape = [2, 2, 2], pads = [0, 0, 0, 0, 0, 0], strides = [2, 2, 2]](%f_left)
#   %input.16 = Conv[dilations = [1, 1, 1], group = 1, kernel_shape = [3, 3, 3], pads = [0, 0, 0, 0, 0, 0], strides = [1, 1, 1]](%input.12, %architecture.unet.0.l_conv.1.conv_pass.0.weight, %architecture.unet.0.l_conv.1.conv_pass.0.bias)
#   %input.20 = Relu(%input.16)
#   %input.24 = Conv[dilations = [1, 1, 1], group = 1, kernel_shape = [3, 3, 3], pads = [0, 0, 0, 0, 0, 0], strides = [1, 1, 1]](%input.20, %architecture.unet.0.l_conv.1.conv_pass.2.weight, %architecture.unet.0.l_conv.1.conv_pass.2.bias)
#   %f_left.3 = Relu(%input.24)
#   %input.28 = MaxPool[ceil_mode = 0, kernel_shape = [3, 3, 3], pads = [0, 0, 0, 0, 0, 0], strides = [3, 3, 3]](%f_left.3)
#   %input.32 = Conv[dilations = [1, 1, 1], group = 1, kernel_shape = [3, 3, 3], pads = [0, 0, 0, 0, 0, 0], strides = [1, 1, 1]](%input.28, %architecture.unet.0.l_conv.2.conv_pass.0.weight, %architecture.unet.0.l_conv.2.conv_pass.0.bias)
#   %input.36 = Relu(%input.32)
#   %input.40 = Conv[dilations = [1, 1, 1], group = 1, kernel_shape = [3, 3, 3], pads = [0, 0, 0, 0, 0, 0], strides = [1, 1, 1]](%input.36, %architecture.unet.0.l_conv.2.conv_pass.2.weight, %architecture.unet.0.l_conv.2.conv_pass.2.bias)
#   %f_left.7 = Relu(%input.40)
#   %input.44 = MaxPool[ceil_mode = 0, kernel_shape = [3, 3, 3], pads = [0, 0, 0, 0, 0, 0], strides = [3, 3, 3]](%f_left.7)
#   %input.48 = Conv[dilations = [1, 1, 1], group = 1, kernel_shape = [3, 3, 3], pads = [0, 0, 0, 0, 0, 0], strides = [1, 1, 1]](%input.44, %architecture.unet.0.l_conv.3.conv_pass.0.weight, %architecture.unet.0.l_conv.3.conv_pass.0.bias)
#   %input.52 = Relu(%input.48)
#   %input.56 = Conv[dilations = [1, 1, 1], group = 1, kernel_shape = [3, 3, 3], pads = [0, 0, 0, 0, 0, 0], strides = [1, 1, 1]](%input.52, %architecture.unet.0.l_conv.3.conv_pass.2.weight, %architecture.unet.0.l_conv.3.conv_pass.2.bias)
#   %input.60 = Relu(%input.56)
#   %onnx::Resize_65 = Constant[value = <Tensor>]()
#   %input.64 = Resize[coordinate_transformation_mode = 'asymmetric', cubic_coeff_a = -0.75, mode = 'nearest', nearest_mode = 'floor'](%input.60, %onnx::Resize_65, %onnx::Resize_641)
#   %input.68 = Conv[dilations = [1, 1, 1], group = 1, kernel_shape = [1, 1, 1], pads = [0, 0, 0, 0, 0, 0], strides = [1, 1, 1]](%input.64, %architecture.unet.0.r_up.0.2.up.1.weight, %architecture.unet.0.r_up.0.2.up.1.bias)
#   %g_up = Relu(%input.68)
#   %onnx::Gather_69 = Shape(%g_up)
#   %onnx::Gather_70 = Constant[value = <Scalar Tensor []>]()
#   %onnx::Sub_71 = Gather[axis = 0](%onnx::Gather_69, %onnx::Gather_70)
#   %onnx::Gather_72 = Shape(%g_up)
#   %onnx::Gather_73 = Constant[value = <Scalar Tensor []>]()
#   %onnx::Sub_74 = Gather[axis = 0](%onnx::Gather_72, %onnx::Gather_73)
#   %onnx::Gather_75 = Shape(%g_up)
#   %onnx::Gather_76 = Constant[value = <Scalar Tensor []>]()
#   %onnx::Sub_77 = Gather[axis = 0](%onnx::Gather_75, %onnx::Gather_76)
#   %onnx::Gather_78 = Shape(%g_up)
#   %onnx::Gather_79 = Constant[value = <Scalar Tensor []>]()
#   %onnx::Sub_80 = Gather[axis = 0](%onnx::Gather_78, %onnx::Gather_79)
#   %onnx::Gather_81 = Shape(%g_up)
#   %onnx::Gather_82 = Constant[value = <Scalar Tensor []>]()
#   %onnx::Sub_83 = Gather[axis = 0](%onnx::Gather_81, %onnx::Gather_82)
#   %onnx::Gather_84 = Shape(%g_up)
#   %onnx::Gather_85 = Constant[value = <Scalar Tensor []>]()
#   %onnx::Sub_86 = Gather[axis = 0](%onnx::Gather_84, %onnx::Gather_85)
#   %onnx::Gather_87 = Shape(%g_up)
#   %onnx::Gather_88 = Constant[value = <Scalar Tensor []>]()
#   %onnx::Sub_89 = Gather[axis = 0](%onnx::Gather_87, %onnx::Gather_88)
#   %onnx::Div_90 = Sub(%onnx::Sub_77, %onnx::Sub_71)
#   %onnx::Div_91 = Constant[value = <Scalar Tensor []>]()
#   %onnx::Cast_92 = Div(%onnx::Div_90, %onnx::Div_91)
#   %onnx::Cast_93 = Cast[to = 7](%onnx::Cast_92)
#   %onnx::Add_94 = Cast[to = 7](%onnx::Cast_93)
#   %onnx::Div_95 = Sub(%onnx::Sub_80, %onnx::Sub_74)
#   %onnx::Div_96 = Constant[value = <Scalar Tensor []>]()
#   %onnx::Cast_97 = Div(%onnx::Div_95, %onnx::Div_96)
#   %onnx::Cast_98 = Cast[to = 7](%onnx::Cast_97)
#   %onnx::Add_99 = Cast[to = 7](%onnx::Cast_98)
#   %onnx::Sub_100 = Constant[value = <Scalar Tensor []>]()
#   %onnx::Div_101 = Sub(%onnx::Sub_83, %onnx::Sub_100)
#   %onnx::Div_102 = Constant[value = <Scalar Tensor []>]()
#   %onnx::Cast_103 = Div(%onnx::Div_101, %onnx::Div_102)
#   %onnx::Cast_104 = Cast[to = 7](%onnx::Cast_103)
#   %onnx::Add_105 = Cast[to = 7](%onnx::Cast_104)
#   %onnx::Sub_106 = Constant[value = <Scalar Tensor []>]()
#   %onnx::Div_107 = Sub(%onnx::Sub_86, %onnx::Sub_106)
#   %onnx::Div_108 = Constant[value = <Scalar Tensor []>]()
#   %onnx::Cast_109 = Div(%onnx::Div_107, %onnx::Div_108)
#   %onnx::Cast_110 = Cast[to = 7](%onnx::Cast_109)
#   %onnx::Add_111 = Cast[to = 7](%onnx::Cast_110)
#   %onnx::Sub_112 = Constant[value = <Scalar Tensor []>]()
#   %onnx::Div_113 = Sub(%onnx::Sub_89, %onnx::Sub_112)
#   %onnx::Div_114 = Constant[value = <Scalar Tensor []>]()
#   %onnx::Cast_115 = Div(%onnx::Div_113, %onnx::Div_114)
#   %onnx::Cast_116 = Cast[to = 7](%onnx::Cast_115)
#   %onnx::Add_117 = Cast[to = 7](%onnx::Cast_116)
#   %onnx::Unsqueeze_118 = Add(%onnx::Add_94, %onnx::Sub_71)
#   %onnx::Unsqueeze_119 = Add(%onnx::Add_99, %onnx::Sub_74)
#   %onnx::Add_120 = Constant[value = <Scalar Tensor []>]()
#   %onnx::Unsqueeze_121 = Add(%onnx::Add_105, %onnx::Add_120)
#   %onnx::Add_122 = Constant[value = <Scalar Tensor []>]()
#   %onnx::Unsqueeze_123 = Add(%onnx::Add_111, %onnx::Add_122)
#   %onnx::Add_124 = Constant[value = <Scalar Tensor []>]()
#   %onnx::Unsqueeze_125 = Add(%onnx::Add_117, %onnx::Add_124)
#   %onnx::Slice_127 = Unsqueeze[axes = [0]](%onnx::Add_94)
#   %onnx::Slice_128 = Unsqueeze[axes = [0]](%onnx::Unsqueeze_118)
#   %onnx::Slice_130 = Constant[value = <Tensor>]()
#   %onnx::Slice_131 = Slice(%g_up, %onnx::Slice_127, %onnx::Slice_128, %onnx::Slice_642, %onnx::Slice_130)
#   %onnx::Slice_133 = Unsqueeze[axes = [0]](%onnx::Add_99)
#   %onnx::Slice_134 = Unsqueeze[axes = [0]](%onnx::Unsqueeze_119)
#   %onnx::Slice_136 = Constant[value = <Tensor>]()
#   %onnx::Slice_137 = Slice(%onnx::Slice_131, %onnx::Slice_133, %onnx::Slice_134, %onnx::Slice_643, %onnx::Slice_136)
#   %onnx::Slice_139 = Unsqueeze[axes = [0]](%onnx::Add_105)
#   %onnx::Slice_140 = Unsqueeze[axes = [0]](%onnx::Unsqueeze_121)
#   %onnx::Slice_142 = Constant[value = <Tensor>]()
#   %onnx::Slice_143 = Slice(%onnx::Slice_137, %onnx::Slice_139, %onnx::Slice_140, %onnx::Slice_644, %onnx::Slice_142)
#   %onnx::Slice_145 = Unsqueeze[axes = [0]](%onnx::Add_111)
#   %onnx::Slice_146 = Unsqueeze[axes = [0]](%onnx::Unsqueeze_123)
#   %onnx::Slice_148 = Constant[value = <Tensor>]()
#   %onnx::Slice_149 = Slice(%onnx::Slice_143, %onnx::Slice_145, %onnx::Slice_146, %onnx::Slice_645, %onnx::Slice_148)
#   %onnx::Slice_151 = Unsqueeze[axes = [0]](%onnx::Add_117)
#   %onnx::Slice_152 = Unsqueeze[axes = [0]](%onnx::Unsqueeze_125)
#   %onnx::Slice_154 = Constant[value = <Tensor>]()
#   %onnx::Shape_155 = Slice(%onnx::Slice_149, %onnx::Slice_151, %onnx::Slice_152, %onnx::Slice_646, %onnx::Slice_154)
#   %onnx::Gather_156 = Shape(%onnx::Shape_155)
#   %onnx::Gather_157 = Constant[value = <Scalar Tensor []>]()
#   %onnx::Sub_158 = Gather[axis = 0](%onnx::Gather_156, %onnx::Gather_157)
#   %onnx::Gather_159 = Shape(%onnx::Shape_155)
#   %onnx::Gather_160 = Constant[value = <Scalar Tensor []>]()
#   %onnx::Sub_161 = Gather[axis = 0](%onnx::Gather_159, %onnx::Gather_160)
#   %onnx::Gather_162 = Shape(%onnx::Shape_155)
#   %onnx::Gather_163 = Constant[value = <Scalar Tensor []>]()
#   %onnx::Sub_164 = Gather[axis = 0](%onnx::Gather_162, %onnx::Gather_163)
#   %onnx::Gather_165 = Shape(%f_left.7)
#   %onnx::Gather_166 = Constant[value = <Scalar Tensor []>]()
#   %onnx::Sub_167 = Gather[axis = 0](%onnx::Gather_165, %onnx::Gather_166)
#   %onnx::Gather_168 = Shape(%f_left.7)
#   %onnx::Gather_169 = Constant[value = <Scalar Tensor []>]()
#   %onnx::Sub_170 = Gather[axis = 0](%onnx::Gather_168, %onnx::Gather_169)
#   %onnx::Gather_171 = Shape(%f_left.7)
#   %onnx::Gather_172 = Constant[value = <Scalar Tensor []>]()
#   %onnx::Sub_173 = Gather[axis = 0](%onnx::Gather_171, %onnx::Gather_172)
#   %onnx::Gather_174 = Shape(%f_left.7)
#   %onnx::Gather_175 = Constant[value = <Scalar Tensor []>]()
#   %onnx::Sub_176 = Gather[axis = 0](%onnx::Gather_174, %onnx::Gather_175)
#   %onnx::Gather_177 = Shape(%f_left.7)
#   %onnx::Gather_178 = Constant[value = <Scalar Tensor []>]()
#   %onnx::Sub_179 = Gather[axis = 0](%onnx::Gather_177, %onnx::Gather_178)
#   %onnx::Gather_180 = Shape(%f_left.7)
#   %onnx::Gather_181 = Constant[value = <Scalar Tensor []>]()
#   %onnx::Sub_182 = Gather[axis = 0](%onnx::Gather_180, %onnx::Gather_181)
#   %onnx::Gather_183 = Shape(%f_left.7)
#   %onnx::Gather_184 = Constant[value = <Scalar Tensor []>]()
#   %onnx::Sub_185 = Gather[axis = 0](%onnx::Gather_183, %onnx::Gather_184)
#   %onnx::Div_186 = Sub(%onnx::Sub_173, %onnx::Sub_167)
#   %onnx::Div_187 = Constant[value = <Scalar Tensor []>]()
#   %onnx::Cast_188 = Div(%onnx::Div_186, %onnx::Div_187)
#   %onnx::Cast_189 = Cast[to = 7](%onnx::Cast_188)
#   %onnx::Add_190 = Cast[to = 7](%onnx::Cast_189)
#   %onnx::Div_191 = Sub(%onnx::Sub_176, %onnx::Sub_170)
#   %onnx::Div_192 = Constant[value = <Scalar Tensor []>]()
#   %onnx::Cast_193 = Div(%onnx::Div_191, %onnx::Div_192)
#   %onnx::Cast_194 = Cast[to = 7](%onnx::Cast_193)
#   %onnx::Add_195 = Cast[to = 7](%onnx::Cast_194)
#   %onnx::Div_196 = Sub(%onnx::Sub_179, %onnx::Sub_158)
#   %onnx::Div_197 = Constant[value = <Scalar Tensor []>]()
#   %onnx::Cast_198 = Div(%onnx::Div_196, %onnx::Div_197)
#   %onnx::Cast_199 = Cast[to = 7](%onnx::Cast_198)
#   %onnx::Add_200 = Cast[to = 7](%onnx::Cast_199)
#   %onnx::Div_201 = Sub(%onnx::Sub_182, %onnx::Sub_161)
#   %onnx::Div_202 = Constant[value = <Scalar Tensor []>]()
#   %onnx::Cast_203 = Div(%onnx::Div_201, %onnx::Div_202)
#   %onnx::Cast_204 = Cast[to = 7](%onnx::Cast_203)
#   %onnx::Add_205 = Cast[to = 7](%onnx::Cast_204)
#   %onnx::Div_206 = Sub(%onnx::Sub_185, %onnx::Sub_164)
#   %onnx::Div_207 = Constant[value = <Scalar Tensor []>]()
#   %onnx::Cast_208 = Div(%onnx::Div_206, %onnx::Div_207)
#   %onnx::Cast_209 = Cast[to = 7](%onnx::Cast_208)
#   %onnx::Add_210 = Cast[to = 7](%onnx::Cast_209)
#   %onnx::Unsqueeze_211 = Add(%onnx::Add_190, %onnx::Sub_167)
#   %onnx::Unsqueeze_212 = Add(%onnx::Add_195, %onnx::Sub_170)
#   %onnx::Unsqueeze_213 = Add(%onnx::Add_200, %onnx::Sub_158)
#   %onnx::Unsqueeze_214 = Add(%onnx::Add_205, %onnx::Sub_161)
#   %onnx::Unsqueeze_215 = Add(%onnx::Add_210, %onnx::Sub_164)
#   %onnx::Slice_217 = Unsqueeze[axes = [0]](%onnx::Add_190)
#   %onnx::Slice_218 = Unsqueeze[axes = [0]](%onnx::Unsqueeze_211)
#   %onnx::Slice_220 = Constant[value = <Tensor>]()
#   %onnx::Slice_221 = Slice(%f_left.7, %onnx::Slice_217, %onnx::Slice_218, %onnx::Slice_647, %onnx::Slice_220)
#   %onnx::Slice_223 = Unsqueeze[axes = [0]](%onnx::Add_195)
#   %onnx::Slice_224 = Unsqueeze[axes = [0]](%onnx::Unsqueeze_212)
#   %onnx::Slice_226 = Constant[value = <Tensor>]()
#   %onnx::Slice_227 = Slice(%onnx::Slice_221, %onnx::Slice_223, %onnx::Slice_224, %onnx::Slice_648, %onnx::Slice_226)
#   %onnx::Slice_229 = Unsqueeze[axes = [0]](%onnx::Add_200)
#   %onnx::Slice_230 = Unsqueeze[axes = [0]](%onnx::Unsqueeze_213)
#   %onnx::Slice_232 = Constant[value = <Tensor>]()
#   %onnx::Slice_233 = Slice(%onnx::Slice_227, %onnx::Slice_229, %onnx::Slice_230, %onnx::Slice_649, %onnx::Slice_232)
#   %onnx::Slice_235 = Unsqueeze[axes = [0]](%onnx::Add_205)
#   %onnx::Slice_236 = Unsqueeze[axes = [0]](%onnx::Unsqueeze_214)
#   %onnx::Slice_238 = Constant[value = <Tensor>]()
#   %onnx::Slice_239 = Slice(%onnx::Slice_233, %onnx::Slice_235, %onnx::Slice_236, %onnx::Slice_650, %onnx::Slice_238)
#   %onnx::Slice_241 = Unsqueeze[axes = [0]](%onnx::Add_210)
#   %onnx::Slice_242 = Unsqueeze[axes = [0]](%onnx::Unsqueeze_215)
#   %onnx::Slice_244 = Constant[value = <Tensor>]()
#   %onnx::Concat_245 = Slice(%onnx::Slice_239, %onnx::Slice_241, %onnx::Slice_242, %onnx::Slice_651, %onnx::Slice_244)
#   %input.72 = Concat[axis = 1](%onnx::Concat_245, %onnx::Shape_155)
#   %input.76 = Conv[dilations = [1, 1, 1], group = 1, kernel_shape = [3, 3, 3], pads = [0, 0, 0, 0, 0, 0], strides = [1, 1, 1]](%input.72, %architecture.unet.0.r_conv.0.2.conv_pass.0.weight, %architecture.unet.0.r_conv.0.2.conv_pass.0.bias)
#   %input.80 = Relu(%input.76)
#   %input.84 = Conv[dilations = [1, 1, 1], group = 1, kernel_shape = [3, 3, 3], pads = [0, 0, 0, 0, 0, 0], strides = [1, 1, 1]](%input.80, %architecture.unet.0.r_conv.0.2.conv_pass.2.weight, %architecture.unet.0.r_conv.0.2.conv_pass.2.bias)
#   %input.88 = Relu(%input.84)
#   %onnx::Resize_254 = Constant[value = <Tensor>]()
#   %input.92 = Resize[coordinate_transformation_mode = 'asymmetric', cubic_coeff_a = -0.75, mode = 'nearest', nearest_mode = 'floor'](%input.88, %onnx::Resize_254, %onnx::Resize_652)
#   %input.96 = Conv[dilations = [1, 1, 1], group = 1, kernel_shape = [1, 1, 1], pads = [0, 0, 0, 0, 0, 0], strides = [1, 1, 1]](%input.92, %architecture.unet.0.r_up.0.1.up.1.weight, %architecture.unet.0.r_up.0.1.up.1.bias)
#   %g_up.3 = Relu(%input.96)
#   %onnx::Gather_258 = Shape(%g_up.3)
#   %onnx::Gather_259 = Constant[value = <Scalar Tensor []>]()
#   %onnx::Sub_260 = Gather[axis = 0](%onnx::Gather_258, %onnx::Gather_259)
#   %onnx::Gather_261 = Shape(%g_up.3)
#   %onnx::Gather_262 = Constant[value = <Scalar Tensor []>]()
#   %onnx::Sub_263 = Gather[axis = 0](%onnx::Gather_261, %onnx::Gather_262)
#   %onnx::Gather_264 = Shape(%g_up.3)
#   %onnx::Gather_265 = Constant[value = <Scalar Tensor []>]()
#   %onnx::Sub_266 = Gather[axis = 0](%onnx::Gather_264, %onnx::Gather_265)
#   %onnx::Gather_267 = Shape(%g_up.3)
#   %onnx::Gather_268 = Constant[value = <Scalar Tensor []>]()
#   %onnx::Sub_269 = Gather[axis = 0](%onnx::Gather_267, %onnx::Gather_268)
#   %onnx::Gather_270 = Shape(%g_up.3)
#   %onnx::Gather_271 = Constant[value = <Scalar Tensor []>]()
#   %onnx::Sub_272 = Gather[axis = 0](%onnx::Gather_270, %onnx::Gather_271)
#   %onnx::Gather_273 = Shape(%g_up.3)
#   %onnx::Gather_274 = Constant[value = <Scalar Tensor []>]()
#   %onnx::Sub_275 = Gather[axis = 0](%onnx::Gather_273, %onnx::Gather_274)
#   %onnx::Gather_276 = Shape(%g_up.3)
#   %onnx::Gather_277 = Constant[value = <Scalar Tensor []>]()
#   %onnx::Sub_278 = Gather[axis = 0](%onnx::Gather_276, %onnx::Gather_277)
#   %onnx::Div_279 = Sub(%onnx::Sub_266, %onnx::Sub_260)
#   %onnx::Div_280 = Constant[value = <Scalar Tensor []>]()
#   %onnx::Cast_281 = Div(%onnx::Div_279, %onnx::Div_280)
#   %onnx::Cast_282 = Cast[to = 7](%onnx::Cast_281)
#   %onnx::Add_283 = Cast[to = 7](%onnx::Cast_282)
#   %onnx::Div_284 = Sub(%onnx::Sub_269, %onnx::Sub_263)
#   %onnx::Div_285 = Constant[value = <Scalar Tensor []>]()
#   %onnx::Cast_286 = Div(%onnx::Div_284, %onnx::Div_285)
#   %onnx::Cast_287 = Cast[to = 7](%onnx::Cast_286)
#   %onnx::Add_288 = Cast[to = 7](%onnx::Cast_287)
#   %onnx::Sub_289 = Constant[value = <Scalar Tensor []>]()
#   %onnx::Div_290 = Sub(%onnx::Sub_272, %onnx::Sub_289)
#   %onnx::Div_291 = Constant[value = <Scalar Tensor []>]()
#   %onnx::Cast_292 = Div(%onnx::Div_290, %onnx::Div_291)
#   %onnx::Cast_293 = Cast[to = 7](%onnx::Cast_292)
#   %onnx::Add_294 = Cast[to = 7](%onnx::Cast_293)
#   %onnx::Sub_295 = Constant[value = <Scalar Tensor []>]()
#   %onnx::Div_296 = Sub(%onnx::Sub_275, %onnx::Sub_295)
#   %onnx::Div_297 = Constant[value = <Scalar Tensor []>]()
#   %onnx::Cast_298 = Div(%onnx::Div_296, %onnx::Div_297)
#   %onnx::Cast_299 = Cast[to = 7](%onnx::Cast_298)
#   %onnx::Add_300 = Cast[to = 7](%onnx::Cast_299)
#   %onnx::Sub_301 = Constant[value = <Scalar Tensor []>]()
#   %onnx::Div_302 = Sub(%onnx::Sub_278, %onnx::Sub_301)
#   %onnx::Div_303 = Constant[value = <Scalar Tensor []>]()
#   %onnx::Cast_304 = Div(%onnx::Div_302, %onnx::Div_303)
#   %onnx::Cast_305 = Cast[to = 7](%onnx::Cast_304)
#   %onnx::Add_306 = Cast[to = 7](%onnx::Cast_305)
#   %onnx::Unsqueeze_307 = Add(%onnx::Add_283, %onnx::Sub_260)
#   %onnx::Unsqueeze_308 = Add(%onnx::Add_288, %onnx::Sub_263)
#   %onnx::Add_309 = Constant[value = <Scalar Tensor []>]()
#   %onnx::Unsqueeze_310 = Add(%onnx::Add_294, %onnx::Add_309)
#   %onnx::Add_311 = Constant[value = <Scalar Tensor []>]()
#   %onnx::Unsqueeze_312 = Add(%onnx::Add_300, %onnx::Add_311)
#   %onnx::Add_313 = Constant[value = <Scalar Tensor []>]()
#   %onnx::Unsqueeze_314 = Add(%onnx::Add_306, %onnx::Add_313)
#   %onnx::Slice_316 = Unsqueeze[axes = [0]](%onnx::Add_283)
#   %onnx::Slice_317 = Unsqueeze[axes = [0]](%onnx::Unsqueeze_307)
#   %onnx::Slice_319 = Constant[value = <Tensor>]()
#   %onnx::Slice_320 = Slice(%g_up.3, %onnx::Slice_316, %onnx::Slice_317, %onnx::Slice_653, %onnx::Slice_319)
#   %onnx::Slice_322 = Unsqueeze[axes = [0]](%onnx::Add_288)
#   %onnx::Slice_323 = Unsqueeze[axes = [0]](%onnx::Unsqueeze_308)
#   %onnx::Slice_325 = Constant[value = <Tensor>]()
#   %onnx::Slice_326 = Slice(%onnx::Slice_320, %onnx::Slice_322, %onnx::Slice_323, %onnx::Slice_654, %onnx::Slice_325)
#   %onnx::Slice_328 = Unsqueeze[axes = [0]](%onnx::Add_294)
#   %onnx::Slice_329 = Unsqueeze[axes = [0]](%onnx::Unsqueeze_310)
#   %onnx::Slice_331 = Constant[value = <Tensor>]()
#   %onnx::Slice_332 = Slice(%onnx::Slice_326, %onnx::Slice_328, %onnx::Slice_329, %onnx::Slice_655, %onnx::Slice_331)
#   %onnx::Slice_334 = Unsqueeze[axes = [0]](%onnx::Add_300)
#   %onnx::Slice_335 = Unsqueeze[axes = [0]](%onnx::Unsqueeze_312)
#   %onnx::Slice_337 = Constant[value = <Tensor>]()
#   %onnx::Slice_338 = Slice(%onnx::Slice_332, %onnx::Slice_334, %onnx::Slice_335, %onnx::Slice_656, %onnx::Slice_337)
#   %onnx::Slice_340 = Unsqueeze[axes = [0]](%onnx::Add_306)
#   %onnx::Slice_341 = Unsqueeze[axes = [0]](%onnx::Unsqueeze_314)
#   %onnx::Slice_343 = Constant[value = <Tensor>]()
#   %onnx::Shape_344 = Slice(%onnx::Slice_338, %onnx::Slice_340, %onnx::Slice_341, %onnx::Slice_657, %onnx::Slice_343)
#   %onnx::Gather_345 = Shape(%onnx::Shape_344)
#   %onnx::Gather_346 = Constant[value = <Scalar Tensor []>]()
#   %onnx::Sub_347 = Gather[axis = 0](%onnx::Gather_345, %onnx::Gather_346)
#   %onnx::Gather_348 = Shape(%onnx::Shape_344)
#   %onnx::Gather_349 = Constant[value = <Scalar Tensor []>]()
#   %onnx::Sub_350 = Gather[axis = 0](%onnx::Gather_348, %onnx::Gather_349)
#   %onnx::Gather_351 = Shape(%onnx::Shape_344)
#   %onnx::Gather_352 = Constant[value = <Scalar Tensor []>]()
#   %onnx::Sub_353 = Gather[axis = 0](%onnx::Gather_351, %onnx::Gather_352)
#   %onnx::Gather_354 = Shape(%f_left.3)
#   %onnx::Gather_355 = Constant[value = <Scalar Tensor []>]()
#   %onnx::Sub_356 = Gather[axis = 0](%onnx::Gather_354, %onnx::Gather_355)
#   %onnx::Gather_357 = Shape(%f_left.3)
#   %onnx::Gather_358 = Constant[value = <Scalar Tensor []>]()
#   %onnx::Sub_359 = Gather[axis = 0](%onnx::Gather_357, %onnx::Gather_358)
#   %onnx::Gather_360 = Shape(%f_left.3)
#   %onnx::Gather_361 = Constant[value = <Scalar Tensor []>]()
#   %onnx::Sub_362 = Gather[axis = 0](%onnx::Gather_360, %onnx::Gather_361)
#   %onnx::Gather_363 = Shape(%f_left.3)
#   %onnx::Gather_364 = Constant[value = <Scalar Tensor []>]()
#   %onnx::Sub_365 = Gather[axis = 0](%onnx::Gather_363, %onnx::Gather_364)
#   %onnx::Gather_366 = Shape(%f_left.3)
#   %onnx::Gather_367 = Constant[value = <Scalar Tensor []>]()
#   %onnx::Sub_368 = Gather[axis = 0](%onnx::Gather_366, %onnx::Gather_367)
#   %onnx::Gather_369 = Shape(%f_left.3)
#   %onnx::Gather_370 = Constant[value = <Scalar Tensor []>]()
#   %onnx::Sub_371 = Gather[axis = 0](%onnx::Gather_369, %onnx::Gather_370)
#   %onnx::Gather_372 = Shape(%f_left.3)
#   %onnx::Gather_373 = Constant[value = <Scalar Tensor []>]()
#   %onnx::Sub_374 = Gather[axis = 0](%onnx::Gather_372, %onnx::Gather_373)
#   %onnx::Div_375 = Sub(%onnx::Sub_362, %onnx::Sub_356)
#   %onnx::Div_376 = Constant[value = <Scalar Tensor []>]()
#   %onnx::Cast_377 = Div(%onnx::Div_375, %onnx::Div_376)
#   %onnx::Cast_378 = Cast[to = 7](%onnx::Cast_377)
#   %onnx::Add_379 = Cast[to = 7](%onnx::Cast_378)
#   %onnx::Div_380 = Sub(%onnx::Sub_365, %onnx::Sub_359)
#   %onnx::Div_381 = Constant[value = <Scalar Tensor []>]()
#   %onnx::Cast_382 = Div(%onnx::Div_380, %onnx::Div_381)
#   %onnx::Cast_383 = Cast[to = 7](%onnx::Cast_382)
#   %onnx::Add_384 = Cast[to = 7](%onnx::Cast_383)
#   %onnx::Div_385 = Sub(%onnx::Sub_368, %onnx::Sub_347)
#   %onnx::Div_386 = Constant[value = <Scalar Tensor []>]()
#   %onnx::Cast_387 = Div(%onnx::Div_385, %onnx::Div_386)
#   %onnx::Cast_388 = Cast[to = 7](%onnx::Cast_387)
#   %onnx::Add_389 = Cast[to = 7](%onnx::Cast_388)
#   %onnx::Div_390 = Sub(%onnx::Sub_371, %onnx::Sub_350)
#   %onnx::Div_391 = Constant[value = <Scalar Tensor []>]()
#   %onnx::Cast_392 = Div(%onnx::Div_390, %onnx::Div_391)
#   %onnx::Cast_393 = Cast[to = 7](%onnx::Cast_392)
#   %onnx::Add_394 = Cast[to = 7](%onnx::Cast_393)
#   %onnx::Div_395 = Sub(%onnx::Sub_374, %onnx::Sub_353)
#   %onnx::Div_396 = Constant[value = <Scalar Tensor []>]()
#   %onnx::Cast_397 = Div(%onnx::Div_395, %onnx::Div_396)
#   %onnx::Cast_398 = Cast[to = 7](%onnx::Cast_397)
#   %onnx::Add_399 = Cast[to = 7](%onnx::Cast_398)
#   %onnx::Unsqueeze_400 = Add(%onnx::Add_379, %onnx::Sub_356)
#   %onnx::Unsqueeze_401 = Add(%onnx::Add_384, %onnx::Sub_359)
#   %onnx::Unsqueeze_402 = Add(%onnx::Add_389, %onnx::Sub_347)
#   %onnx::Unsqueeze_403 = Add(%onnx::Add_394, %onnx::Sub_350)
#   %onnx::Unsqueeze_404 = Add(%onnx::Add_399, %onnx::Sub_353)
#   %onnx::Slice_406 = Unsqueeze[axes = [0]](%onnx::Add_379)
#   %onnx::Slice_407 = Unsqueeze[axes = [0]](%onnx::Unsqueeze_400)
#   %onnx::Slice_409 = Constant[value = <Tensor>]()
#   %onnx::Slice_410 = Slice(%f_left.3, %onnx::Slice_406, %onnx::Slice_407, %onnx::Slice_658, %onnx::Slice_409)
#   %onnx::Slice_412 = Unsqueeze[axes = [0]](%onnx::Add_384)
#   %onnx::Slice_413 = Unsqueeze[axes = [0]](%onnx::Unsqueeze_401)
#   %onnx::Slice_415 = Constant[value = <Tensor>]()
#   %onnx::Slice_416 = Slice(%onnx::Slice_410, %onnx::Slice_412, %onnx::Slice_413, %onnx::Slice_659, %onnx::Slice_415)
#   %onnx::Slice_418 = Unsqueeze[axes = [0]](%onnx::Add_389)
#   %onnx::Slice_419 = Unsqueeze[axes = [0]](%onnx::Unsqueeze_402)
#   %onnx::Slice_421 = Constant[value = <Tensor>]()
#   %onnx::Slice_422 = Slice(%onnx::Slice_416, %onnx::Slice_418, %onnx::Slice_419, %onnx::Slice_660, %onnx::Slice_421)
#   %onnx::Slice_424 = Unsqueeze[axes = [0]](%onnx::Add_394)
#   %onnx::Slice_425 = Unsqueeze[axes = [0]](%onnx::Unsqueeze_403)
#   %onnx::Slice_427 = Constant[value = <Tensor>]()
#   %onnx::Slice_428 = Slice(%onnx::Slice_422, %onnx::Slice_424, %onnx::Slice_425, %onnx::Slice_661, %onnx::Slice_427)
#   %onnx::Slice_430 = Unsqueeze[axes = [0]](%onnx::Add_399)
#   %onnx::Slice_431 = Unsqueeze[axes = [0]](%onnx::Unsqueeze_404)
#   %onnx::Slice_433 = Constant[value = <Tensor>]()
#   %onnx::Concat_434 = Slice(%onnx::Slice_428, %onnx::Slice_430, %onnx::Slice_431, %onnx::Slice_662, %onnx::Slice_433)
#   %input.100 = Concat[axis = 1](%onnx::Concat_434, %onnx::Shape_344)
#   %input.104 = Conv[dilations = [1, 1, 1], group = 1, kernel_shape = [3, 3, 3], pads = [0, 0, 0, 0, 0, 0], strides = [1, 1, 1]](%input.100, %architecture.unet.0.r_conv.0.1.conv_pass.0.weight, %architecture.unet.0.r_conv.0.1.conv_pass.0.bias)
#   %input.108 = Relu(%input.104)
#   %input.112 = Conv[dilations = [1, 1, 1], group = 1, kernel_shape = [3, 3, 3], pads = [0, 0, 0, 0, 0, 0], strides = [1, 1, 1]](%input.108, %architecture.unet.0.r_conv.0.1.conv_pass.2.weight, %architecture.unet.0.r_conv.0.1.conv_pass.2.bias)
#   %input.116 = Relu(%input.112)
#   %onnx::Resize_443 = Constant[value = <Tensor>]()
#   %input.120 = Resize[coordinate_transformation_mode = 'asymmetric', cubic_coeff_a = -0.75, mode = 'nearest', nearest_mode = 'floor'](%input.116, %onnx::Resize_443, %onnx::Resize_663)
#   %input.124 = Conv[dilations = [1, 1, 1], group = 1, kernel_shape = [1, 1, 1], pads = [0, 0, 0, 0, 0, 0], strides = [1, 1, 1]](%input.120, %architecture.unet.0.r_up.0.0.up.1.weight, %architecture.unet.0.r_up.0.0.up.1.bias)
#   %g_up.7 = Relu(%input.124)
#   %onnx::Gather_447 = Shape(%g_up.7)
#   %onnx::Gather_448 = Constant[value = <Scalar Tensor []>]()
#   %onnx::Sub_449 = Gather[axis = 0](%onnx::Gather_447, %onnx::Gather_448)
#   %onnx::Gather_450 = Shape(%g_up.7)
#   %onnx::Gather_451 = Constant[value = <Scalar Tensor []>]()
#   %onnx::Sub_452 = Gather[axis = 0](%onnx::Gather_450, %onnx::Gather_451)
#   %onnx::Gather_453 = Shape(%g_up.7)
#   %onnx::Gather_454 = Constant[value = <Scalar Tensor []>]()
#   %onnx::Sub_455 = Gather[axis = 0](%onnx::Gather_453, %onnx::Gather_454)
#   %onnx::Gather_456 = Shape(%g_up.7)
#   %onnx::Gather_457 = Constant[value = <Scalar Tensor []>]()
#   %onnx::Sub_458 = Gather[axis = 0](%onnx::Gather_456, %onnx::Gather_457)
#   %onnx::Gather_459 = Shape(%g_up.7)
#   %onnx::Gather_460 = Constant[value = <Scalar Tensor []>]()
#   %onnx::Sub_461 = Gather[axis = 0](%onnx::Gather_459, %onnx::Gather_460)
#   %onnx::Gather_462 = Shape(%g_up.7)
#   %onnx::Gather_463 = Constant[value = <Scalar Tensor []>]()
#   %onnx::Sub_464 = Gather[axis = 0](%onnx::Gather_462, %onnx::Gather_463)
#   %onnx::Gather_465 = Shape(%g_up.7)
#   %onnx::Gather_466 = Constant[value = <Scalar Tensor []>]()
#   %onnx::Sub_467 = Gather[axis = 0](%onnx::Gather_465, %onnx::Gather_466)
#   %onnx::Div_468 = Sub(%onnx::Sub_455, %onnx::Sub_449)
#   %onnx::Div_469 = Constant[value = <Scalar Tensor []>]()
#   %onnx::Cast_470 = Div(%onnx::Div_468, %onnx::Div_469)
#   %onnx::Cast_471 = Cast[to = 7](%onnx::Cast_470)
#   %onnx::Add_472 = Cast[to = 7](%onnx::Cast_471)
#   %onnx::Div_473 = Sub(%onnx::Sub_458, %onnx::Sub_452)
#   %onnx::Div_474 = Constant[value = <Scalar Tensor []>]()
#   %onnx::Cast_475 = Div(%onnx::Div_473, %onnx::Div_474)
#   %onnx::Cast_476 = Cast[to = 7](%onnx::Cast_475)
#   %onnx::Add_477 = Cast[to = 7](%onnx::Cast_476)
#   %onnx::Sub_478 = Constant[value = <Scalar Tensor []>]()
#   %onnx::Div_479 = Sub(%onnx::Sub_461, %onnx::Sub_478)
#   %onnx::Div_480 = Constant[value = <Scalar Tensor []>]()
#   %onnx::Cast_481 = Div(%onnx::Div_479, %onnx::Div_480)
#   %onnx::Cast_482 = Cast[to = 7](%onnx::Cast_481)
#   %onnx::Add_483 = Cast[to = 7](%onnx::Cast_482)
#   %onnx::Sub_484 = Constant[value = <Scalar Tensor []>]()
#   %onnx::Div_485 = Sub(%onnx::Sub_464, %onnx::Sub_484)
#   %onnx::Div_486 = Constant[value = <Scalar Tensor []>]()
#   %onnx::Cast_487 = Div(%onnx::Div_485, %onnx::Div_486)
#   %onnx::Cast_488 = Cast[to = 7](%onnx::Cast_487)
#   %onnx::Add_489 = Cast[to = 7](%onnx::Cast_488)
#   %onnx::Sub_490 = Constant[value = <Scalar Tensor []>]()
#   %onnx::Div_491 = Sub(%onnx::Sub_467, %onnx::Sub_490)
#   %onnx::Div_492 = Constant[value = <Scalar Tensor []>]()
#   %onnx::Cast_493 = Div(%onnx::Div_491, %onnx::Div_492)
#   %onnx::Cast_494 = Cast[to = 7](%onnx::Cast_493)
#   %onnx::Add_495 = Cast[to = 7](%onnx::Cast_494)
#   %onnx::Unsqueeze_496 = Add(%onnx::Add_472, %onnx::Sub_449)
#   %onnx::Unsqueeze_497 = Add(%onnx::Add_477, %onnx::Sub_452)
#   %onnx::Add_498 = Constant[value = <Scalar Tensor []>]()
#   %onnx::Unsqueeze_499 = Add(%onnx::Add_483, %onnx::Add_498)
#   %onnx::Add_500 = Constant[value = <Scalar Tensor []>]()
#   %onnx::Unsqueeze_501 = Add(%onnx::Add_489, %onnx::Add_500)
#   %onnx::Add_502 = Constant[value = <Scalar Tensor []>]()
#   %onnx::Unsqueeze_503 = Add(%onnx::Add_495, %onnx::Add_502)
#   %onnx::Slice_505 = Unsqueeze[axes = [0]](%onnx::Add_472)
#   %onnx::Slice_506 = Unsqueeze[axes = [0]](%onnx::Unsqueeze_496)
#   %onnx::Slice_508 = Constant[value = <Tensor>]()
#   %onnx::Slice_509 = Slice(%g_up.7, %onnx::Slice_505, %onnx::Slice_506, %onnx::Slice_664, %onnx::Slice_508)
#   %onnx::Slice_511 = Unsqueeze[axes = [0]](%onnx::Add_477)
#   %onnx::Slice_512 = Unsqueeze[axes = [0]](%onnx::Unsqueeze_497)
#   %onnx::Slice_514 = Constant[value = <Tensor>]()
#   %onnx::Slice_515 = Slice(%onnx::Slice_509, %onnx::Slice_511, %onnx::Slice_512, %onnx::Slice_665, %onnx::Slice_514)
#   %onnx::Slice_517 = Unsqueeze[axes = [0]](%onnx::Add_483)
#   %onnx::Slice_518 = Unsqueeze[axes = [0]](%onnx::Unsqueeze_499)
#   %onnx::Slice_520 = Constant[value = <Tensor>]()
#   %onnx::Slice_521 = Slice(%onnx::Slice_515, %onnx::Slice_517, %onnx::Slice_518, %onnx::Slice_666, %onnx::Slice_520)
#   %onnx::Slice_523 = Unsqueeze[axes = [0]](%onnx::Add_489)
#   %onnx::Slice_524 = Unsqueeze[axes = [0]](%onnx::Unsqueeze_501)
#   %onnx::Slice_526 = Constant[value = <Tensor>]()
#   %onnx::Slice_527 = Slice(%onnx::Slice_521, %onnx::Slice_523, %onnx::Slice_524, %onnx::Slice_667, %onnx::Slice_526)
#   %onnx::Slice_529 = Unsqueeze[axes = [0]](%onnx::Add_495)
#   %onnx::Slice_530 = Unsqueeze[axes = [0]](%onnx::Unsqueeze_503)
#   %onnx::Slice_532 = Constant[value = <Tensor>]()
#   %onnx::Shape_533 = Slice(%onnx::Slice_527, %onnx::Slice_529, %onnx::Slice_530, %onnx::Slice_668, %onnx::Slice_532)
#   %onnx::Gather_534 = Shape(%onnx::Shape_533)
#   %onnx::Gather_535 = Constant[value = <Scalar Tensor []>]()
#   %onnx::Sub_536 = Gather[axis = 0](%onnx::Gather_534, %onnx::Gather_535)
#   %onnx::Gather_537 = Shape(%onnx::Shape_533)
#   %onnx::Gather_538 = Constant[value = <Scalar Tensor []>]()
#   %onnx::Sub_539 = Gather[axis = 0](%onnx::Gather_537, %onnx::Gather_538)
#   %onnx::Gather_540 = Shape(%onnx::Shape_533)
#   %onnx::Gather_541 = Constant[value = <Scalar Tensor []>]()
#   %onnx::Sub_542 = Gather[axis = 0](%onnx::Gather_540, %onnx::Gather_541)
#   %onnx::Gather_543 = Shape(%f_left)
#   %onnx::Gather_544 = Constant[value = <Scalar Tensor []>]()
#   %onnx::Sub_545 = Gather[axis = 0](%onnx::Gather_543, %onnx::Gather_544)
#   %onnx::Gather_546 = Shape(%f_left)
#   %onnx::Gather_547 = Constant[value = <Scalar Tensor []>]()
#   %onnx::Sub_548 = Gather[axis = 0](%onnx::Gather_546, %onnx::Gather_547)
#   %onnx::Gather_549 = Shape(%f_left)
#   %onnx::Gather_550 = Constant[value = <Scalar Tensor []>]()
#   %onnx::Sub_551 = Gather[axis = 0](%onnx::Gather_549, %onnx::Gather_550)
#   %onnx::Gather_552 = Shape(%f_left)
#   %onnx::Gather_553 = Constant[value = <Scalar Tensor []>]()
#   %onnx::Sub_554 = Gather[axis = 0](%onnx::Gather_552, %onnx::Gather_553)
#   %onnx::Gather_555 = Shape(%f_left)
#   %onnx::Gather_556 = Constant[value = <Scalar Tensor []>]()
#   %onnx::Sub_557 = Gather[axis = 0](%onnx::Gather_555, %onnx::Gather_556)
#   %onnx::Gather_558 = Shape(%f_left)
#   %onnx::Gather_559 = Constant[value = <Scalar Tensor []>]()
#   %onnx::Sub_560 = Gather[axis = 0](%onnx::Gather_558, %onnx::Gather_559)
#   %onnx::Gather_561 = Shape(%f_left)
#   %onnx::Gather_562 = Constant[value = <Scalar Tensor []>]()
#   %onnx::Sub_563 = Gather[axis = 0](%onnx::Gather_561, %onnx::Gather_562)
#   %onnx::Div_564 = Sub(%onnx::Sub_551, %onnx::Sub_545)
#   %onnx::Div_565 = Constant[value = <Scalar Tensor []>]()
#   %onnx::Cast_566 = Div(%onnx::Div_564, %onnx::Div_565)
#   %onnx::Cast_567 = Cast[to = 7](%onnx::Cast_566)
#   %onnx::Add_568 = Cast[to = 7](%onnx::Cast_567)
#   %onnx::Div_569 = Sub(%onnx::Sub_554, %onnx::Sub_548)
#   %onnx::Div_570 = Constant[value = <Scalar Tensor []>]()
#   %onnx::Cast_571 = Div(%onnx::Div_569, %onnx::Div_570)
#   %onnx::Cast_572 = Cast[to = 7](%onnx::Cast_571)
#   %onnx::Add_573 = Cast[to = 7](%onnx::Cast_572)
#   %onnx::Div_574 = Sub(%onnx::Sub_557, %onnx::Sub_536)
#   %onnx::Div_575 = Constant[value = <Scalar Tensor []>]()
#   %onnx::Cast_576 = Div(%onnx::Div_574, %onnx::Div_575)
#   %onnx::Cast_577 = Cast[to = 7](%onnx::Cast_576)
#   %onnx::Add_578 = Cast[to = 7](%onnx::Cast_577)
#   %onnx::Div_579 = Sub(%onnx::Sub_560, %onnx::Sub_539)
#   %onnx::Div_580 = Constant[value = <Scalar Tensor []>]()
#   %onnx::Cast_581 = Div(%onnx::Div_579, %onnx::Div_580)
#   %onnx::Cast_582 = Cast[to = 7](%onnx::Cast_581)
#   %onnx::Add_583 = Cast[to = 7](%onnx::Cast_582)
#   %onnx::Div_584 = Sub(%onnx::Sub_563, %onnx::Sub_542)
#   %onnx::Div_585 = Constant[value = <Scalar Tensor []>]()
#   %onnx::Cast_586 = Div(%onnx::Div_584, %onnx::Div_585)
#   %onnx::Cast_587 = Cast[to = 7](%onnx::Cast_586)
#   %onnx::Add_588 = Cast[to = 7](%onnx::Cast_587)
#   %onnx::Unsqueeze_589 = Add(%onnx::Add_568, %onnx::Sub_545)
#   %onnx::Unsqueeze_590 = Add(%onnx::Add_573, %onnx::Sub_548)
#   %onnx::Unsqueeze_591 = Add(%onnx::Add_578, %onnx::Sub_536)
#   %onnx::Unsqueeze_592 = Add(%onnx::Add_583, %onnx::Sub_539)
#   %onnx::Unsqueeze_593 = Add(%onnx::Add_588, %onnx::Sub_542)
#   %onnx::Slice_595 = Unsqueeze[axes = [0]](%onnx::Add_568)
#   %onnx::Slice_596 = Unsqueeze[axes = [0]](%onnx::Unsqueeze_589)
#   %onnx::Slice_598 = Constant[value = <Tensor>]()
#   %onnx::Slice_599 = Slice(%f_left, %onnx::Slice_595, %onnx::Slice_596, %onnx::Slice_669, %onnx::Slice_598)
#   %onnx::Slice_601 = Unsqueeze[axes = [0]](%onnx::Add_573)
#   %onnx::Slice_602 = Unsqueeze[axes = [0]](%onnx::Unsqueeze_590)
#   %onnx::Slice_604 = Constant[value = <Tensor>]()
#   %onnx::Slice_605 = Slice(%onnx::Slice_599, %onnx::Slice_601, %onnx::Slice_602, %onnx::Slice_670, %onnx::Slice_604)
#   %onnx::Slice_607 = Unsqueeze[axes = [0]](%onnx::Add_578)
#   %onnx::Slice_608 = Unsqueeze[axes = [0]](%onnx::Unsqueeze_591)
#   %onnx::Slice_610 = Constant[value = <Tensor>]()
#   %onnx::Slice_611 = Slice(%onnx::Slice_605, %onnx::Slice_607, %onnx::Slice_608, %onnx::Slice_671, %onnx::Slice_610)
#   %onnx::Slice_613 = Unsqueeze[axes = [0]](%onnx::Add_583)
#   %onnx::Slice_614 = Unsqueeze[axes = [0]](%onnx::Unsqueeze_592)
#   %onnx::Slice_616 = Constant[value = <Tensor>]()
#   %onnx::Slice_617 = Slice(%onnx::Slice_611, %onnx::Slice_613, %onnx::Slice_614, %onnx::Slice_672, %onnx::Slice_616)
#   %onnx::Slice_619 = Unsqueeze[axes = [0]](%onnx::Add_588)
#   %onnx::Slice_620 = Unsqueeze[axes = [0]](%onnx::Unsqueeze_593)
#   %onnx::Slice_622 = Constant[value = <Tensor>]()
#   %onnx::Concat_623 = Slice(%onnx::Slice_617, %onnx::Slice_619, %onnx::Slice_620, %onnx::Slice_673, %onnx::Slice_622)
#   %input.128 = Concat[axis = 1](%onnx::Concat_623, %onnx::Shape_533)
#   %input.132 = Conv[dilations = [1, 1, 1], group = 1, kernel_shape = [3, 3, 3], pads = [0, 0, 0, 0, 0, 0], strides = [1, 1, 1]](%input.128, %architecture.unet.0.r_conv.0.0.conv_pass.0.weight, %architecture.unet.0.r_conv.0.0.conv_pass.0.bias)
#   %input.136 = Relu(%input.132)
#   %input.140 = Conv[dilations = [1, 1, 1], group = 1, kernel_shape = [3, 3, 3], pads = [0, 0, 0, 0, 0, 0], strides = [1, 1, 1]](%input.136, %architecture.unet.0.r_conv.0.0.conv_pass.2.weight, %architecture.unet.0.r_conv.0.0.conv_pass.2.bias)
#   %input.144 = Relu(%input.140)
#   %onnx::Resize_632 = Constant[value = <Tensor>]()
#   %input.148 = Resize[coordinate_transformation_mode = 'asymmetric', cubic_coeff_a = -0.75, mode = 'nearest', nearest_mode = 'floor'](%input.144, %onnx::Resize_632, %onnx::Resize_674)
#   %input.152 = Conv[dilations = [1, 1, 1], group = 1, kernel_shape = [1, 1, 1], pads = [0, 0, 0, 0, 0, 0], strides = [1, 1, 1]](%input.148, %architecture.unet.1.up.1.weight, %architecture.unet.1.up.1.bias)
#   %input.156 = Relu(%input.152)
#   %input.160 = Conv[dilations = [1, 1, 1], group = 1, kernel_shape = [3, 3, 3], pads = [0, 0, 0, 0, 0, 0], strides = [1, 1, 1]](%input.156, %architecture.unet.2.conv_pass.0.weight, %architecture.unet.2.conv_pass.0.bias)
#   %input.164 = Relu(%input.160)
#   %input.168 = Conv[dilations = [1, 1, 1], group = 1, kernel_shape = [3, 3, 3], pads = [0, 0, 0, 0, 0, 0], strides = [1, 1, 1]](%input.164, %architecture.unet.2.conv_pass.2.weight, %architecture.unet.2.conv_pass.2.bias)
#   %input.172 = Relu(%input.168)
#   %output = Conv[dilations = [1, 1, 1], group = 1, kernel_shape = [1, 1, 1], pads = [0, 0, 0, 0, 0, 0], strides = [1, 1, 1]](%input.172, %prediction_head.weight, %prediction_head.bias)
#   return %output
# }

# %%
import onnxruntime as ort
import numpy as np
import torch
import zarr
import time

zarr_root = zarr.open(f"/groups/cellmap/cellmap/data/jrc_mus-liver/jrc_mus-liver.n5", mode="r",)
print(zarr_root['volumes/raw/s1'].shape)
raw_16nm_data = np.reshape(zarr_root['volumes/raw/s1'][4000:4000+216, 5800:5800+216, 1800:1800+216]/255.0, (1,1,216,216,216))
batch_size = 4
raw_16nm_data = np.concatenate([raw_16nm_data for i in range(batch_size)], axis = 0)
print(raw_16nm_data.shape)
ort_session = ort.InferenceSession("cellmap_model.onnx", providers=['CUDAExecutionProvider', 'CPUExecutionProvider'])

t = time.time()
outputs = ort_session.run(
    None,
    {"input":  raw_16nm_data.astype(np.float32)},
)
print(outputs[0].shape,(time.time() - t)/batch_size)
# Out:
# (4466, 6364, 6373)
# (4, 1, 216, 216, 216)
# 2022-06-30 15:29:29.587187928 [E:onnxruntime:, inference_session.cc:1587 operator()] Exception during initialization: /onnxruntime_src/onnxruntime/core/framework/bfc_arena.cc:342 void* onnxruntime::BFCArena::AllocateRawInternal(size_t, bool) Failed to allocate memory for requested buffer of size 725594112
# ---------------------------------------------------------------------------
# RuntimeException                          Traceback (most recent call last)
# /groups/scicompsoft/home/ackermand/Programming/deeplearning4j-examples/python/cellmap_onnx.ipynb Cell 3' in <cell line: 13>()
#      <a href='vscode-notebook-cell://ssh-remote%2Backermand-ws2/groups/scicompsoft/home/ackermand/Programming/deeplearning4j-examples/python/cellmap_onnx.ipynb#ch0000002vscode-remote?line=10'>11</a> raw_16nm_data = np.concatenate([raw_16nm_data for i in range(batch_size)], axis = 0)
#      <a href='vscode-notebook-cell://ssh-remote%2Backermand-ws2/groups/scicompsoft/home/ackermand/Programming/deeplearning4j-examples/python/cellmap_onnx.ipynb#ch0000002vscode-remote?line=11'>12</a> print(raw_16nm_data.shape)
# ---> <a href='vscode-notebook-cell://ssh-remote%2Backermand-ws2/groups/scicompsoft/home/ackermand/Programming/deeplearning4j-examples/python/cellmap_onnx.ipynb#ch0000002vscode-remote?line=12'>13</a> ort_session = ort.InferenceSession("cellmap_model.onnx", providers=['CUDAExecutionProvider', 'CPUExecutionProvider'])
#      <a href='vscode-notebook-cell://ssh-remote%2Backermand-ws2/groups/scicompsoft/home/ackermand/Programming/deeplearning4j-examples/python/cellmap_onnx.ipynb#ch0000002vscode-remote?line=14'>15</a> t = time.time()
#      <a href='vscode-notebook-cell://ssh-remote%2Backermand-ws2/groups/scicompsoft/home/ackermand/Programming/deeplearning4j-examples/python/cellmap_onnx.ipynb#ch0000002vscode-remote?line=15'>16</a> outputs = ort_session.run(
#      <a href='vscode-notebook-cell://ssh-remote%2Backermand-ws2/groups/scicompsoft/home/ackermand/Programming/deeplearning4j-examples/python/cellmap_onnx.ipynb#ch0000002vscode-remote?line=16'>17</a>     None,
#      <a href='vscode-notebook-cell://ssh-remote%2Backermand-ws2/groups/scicompsoft/home/ackermand/Programming/deeplearning4j-examples/python/cellmap_onnx.ipynb#ch0000002vscode-remote?line=17'>18</a>     {"input":  raw_16nm_data.astype(np.float32)},
#      <a href='vscode-notebook-cell://ssh-remote%2Backermand-ws2/groups/scicompsoft/home/ackermand/Programming/deeplearning4j-examples/python/cellmap_onnx.ipynb#ch0000002vscode-remote?line=18'>19</a> )
#
# File ~/miniconda3/envs/dacapo_deeplearning4j/lib/python3.9/site-packages/onnxruntime/capi/onnxruntime_inference_collection.py:335, in InferenceSession.__init__(self, path_or_bytes, sess_options, providers, provider_options, **kwargs)
#     <a href='file:///groups/scicompsoft/home/ackermand/miniconda3/envs/dacapo_deeplearning4j/lib/python3.9/site-packages/onnxruntime/capi/onnxruntime_inference_collection.py?line=331'>332</a> disabled_optimizers = kwargs['disabled_optimizers'] if 'disabled_optimizers' in kwargs else None
#     <a href='file:///groups/scicompsoft/home/ackermand/miniconda3/envs/dacapo_deeplearning4j/lib/python3.9/site-packages/onnxruntime/capi/onnxruntime_inference_collection.py?line=333'>334</a> try:
# --> <a href='file:///groups/scicompsoft/home/ackermand/miniconda3/envs/dacapo_deeplearning4j/lib/python3.9/site-packages/onnxruntime/capi/onnxruntime_inference_collection.py?line=334'>335</a>     self._create_inference_session(providers, provider_options, disabled_optimizers)
#     <a href='file:///groups/scicompsoft/home/ackermand/miniconda3/envs/dacapo_deeplearning4j/lib/python3.9/site-packages/onnxruntime/capi/onnxruntime_inference_collection.py?line=335'>336</a> except ValueError:
#     <a href='file:///groups/scicompsoft/home/ackermand/miniconda3/envs/dacapo_deeplearning4j/lib/python3.9/site-packages/onnxruntime/capi/onnxruntime_inference_collection.py?line=336'>337</a>     if self._enable_fallback:
#
# File ~/miniconda3/envs/dacapo_deeplearning4j/lib/python3.9/site-packages/onnxruntime/capi/onnxruntime_inference_collection.py:381, in InferenceSession._create_inference_session(self, providers, provider_options, disabled_optimizers)
#     <a href='file:///groups/scicompsoft/home/ackermand/miniconda3/envs/dacapo_deeplearning4j/lib/python3.9/site-packages/onnxruntime/capi/onnxruntime_inference_collection.py?line=377'>378</a>     disabled_optimizers = set(disabled_optimizers)
#     <a href='file:///groups/scicompsoft/home/ackermand/miniconda3/envs/dacapo_deeplearning4j/lib/python3.9/site-packages/onnxruntime/capi/onnxruntime_inference_collection.py?line=379'>380</a> # initialize the C++ InferenceSession
# --> <a href='file:///groups/scicompsoft/home/ackermand/miniconda3/envs/dacapo_deeplearning4j/lib/python3.9/site-packages/onnxruntime/capi/onnxruntime_inference_collection.py?line=380'>381</a> sess.initialize_session(providers, provider_options, disabled_optimizers)
#     <a href='file:///groups/scicompsoft/home/ackermand/miniconda3/envs/dacapo_deeplearning4j/lib/python3.9/site-packages/onnxruntime/capi/onnxruntime_inference_collection.py?line=382'>383</a> self._sess = sess
#     <a href='file:///groups/scicompsoft/home/ackermand/miniconda3/envs/dacapo_deeplearning4j/lib/python3.9/site-packages/onnxruntime/capi/onnxruntime_inference_collection.py?line=383'>384</a> self._sess_options = self._sess.session_options
#
# RuntimeException: [ONNXRuntimeError] : 6 : RUNTIME_EXCEPTION : Exception during initialization: /onnxruntime_src/onnxruntime/core/framework/bfc_arena.cc:342 void* onnxruntime::BFCArena::AllocateRawInternal(size_t, bool) Failed to allocate memory for requested buffer of size 725594112

# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline
print(type(outputs[0][0][1]))
fig, axs = plt.subplots(1, 2)
raw_16nm_data_upsample = raw_16nm_data[0][0]
raw_16nm_data_upsample = raw_16nm_data_upsample.repeat(2, axis=0).repeat(2, axis=1).repeat(2, axis=2)

output = np.zeros((432,432,432))
output[216-34:216+34, 216-34:216+34, 216-34:216+34] = outputs[0][0][8]
#axs[0].imshow(raw_16nm_data_upsample[:,:,216])
#axs[1].imshow(output[:,:,216])
axs[0].imshow(raw_16nm_data_upsample[216-34:216+34, 216-34:216+34, 216])
axs[1].imshow(outputs[0][0][8][:,:,34])
# Out:
# <class 'numpy.ndarray'>

# %%
# attempt batches
import torch
torch.randint(255, (1, 10),dtype = torch.uint8)
# Out:
# tensor([[240, 242, 215,   1, 182,  63, 239, 167, 159, 141]], dtype=torch.uint8)

# %%
import onnxruntime as ort
print( ort.get_device()  )
# Out:
# GPU
